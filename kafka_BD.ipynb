# %% [markdown]
# <a href="https://colab.research.google.com/github/vrishmi/BigData2/blob/master/kafka_BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /usr/local/lib/python3.10/dist-packages (2.4.0)

# %% [markdown]
# ###1. Implement Kafka Producers:
# Producer 1: Inventory Orders Producer  This producer sends messages related to inventory checks.  It should filter and send only messages where type is inventory.
#
# Producer 2: Delivery Orders Producer  This producer handles messages related to the delivery of orders.

# %%
from confluent_kafka import Producer as KP
import socket as S

# Configuration common to both producers
config = {
    'bootstrap.servers': "localhost:9092",
    'client.id': S.gethostname()
}

# Function to acknowledge message delivery
def acked(err, msg):
    if err is not None:
        print("Error delivering message: %s: %s" % (str(msg), str(err)))
    else:
        print("Message sent successfully: %s" % (str(msg)))

# Inventory Orders Producer
producer_inv = KP(config)
def send_inv_msg(data):
    producer_inv.produce('inventory_topic', key=str(data['order_id']), value=str(data), callback=acked)
    producer_inv.poll(0)
    print("Sent inventory message:", data)

# Delivery Orders Producer
producer_del = KP(config)
def send_del_msg(data):
    producer_del.produce('delivery_topic', key=str(data['order_id']), value=str(data), callback=acked)
    producer_del.poll(0)
    print("Sent delivery message:", data)

# Ensure all messages are sent
producer_inv.flush()
producer_del.flush()
# Out:
# 0

# %% [markdown]
# ###2. Implement Kafka Consumers:
# Consumer 1: Inventory Data Consumer  This consumer is responsible for handling inventory data.  It should listen for messages where type is inventory and process them to update
# inventory databases or systems accordingly.

# %%
from confluent_kafka import Consumer as KC, KafkaError as KE

# Common configuration for both consumers
config_cons = {
    'bootstrap.servers': "localhost:9092",
    'group.id': "group1",
    'auto.offset.reset': 'earliest'
}

# Inventory Data Consumer
cons_inv = KC(config_cons)
cons_inv.subscribe(['inventory_topic'])

def consume_inv():
    while True:
        msg = cons_inv.poll(1.0)
        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KE._PARTITION_EOF:
                continue
            else:
                print(msg.error())
                break
        print('Received inventory message: {}'.format(msg.value()))

# Delivery Data Consumer
cons_del = KC(config_cons)
cons_del.subscribe(['delivery_topic'])

def consume_del():
    while True:
        msg = cons_del.poll(1.0)
        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KE._PARTITION_EOF:
                continue
            else:
                print(msg.error())
                break
        print('Received delivery message: {}'.format(msg.value()))

# %% [markdown]
# Consumer 2: Delivery Data Consumer  This consumer manages delivery tasks.  It should listen for messages where type is delivery and perform actions such as
# scheduling deliveries, updating delivery status, and notifying customers. 3. Develop Message Filtering Logic  Develop the logic for each producer to filter messages based on the type field

# %%
from confluent_kafka import Consumer as KCons, KafkaError as KErr
import threading as T

# Common configuration for both consumers
config_cons = {
    'bootstrap.servers': "localhost:9092",
    'group.id': "group1",
    'auto.offset.reset': 'earliest'
}

# Inventory Data Consumer
cons_inv = KCons(config_cons)
cons_inv.subscribe(['inventory_topic'])

def consume_inv():
    while True:
        msg = cons_inv.poll(1.0)
        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KErr._PARTITION_EOF:
                continue
            else:
                print(msg.error())
                break
        print('Received inventory message: {}'.format(msg.value()))

# Delivery Data Consumer
cons_del = KCons(config_cons)
cons_del.subscribe(['delivery_topic'])

def consume_del():
    while True:
        msg = cons_del.poll(1.0)
        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KErr._PARTITION_EOF:
                continue
            else:
                print(msg.error())
                break
        print('Received delivery message: {}'.format(msg.value()))

# Start consuming messages in separate threads
inv_thread = T.Thread(target=consume_inv)
del_thread = T.Thread(target=consume_del)

inv_thread.start()
del_thread.start()

# %%
# Inventory Data Consumer
cons_inv = KCons(config_cons)
cons_inv.subscribe(['inventory_topic'])

# Delivery Data Consumer
cons_del = KCons(config_cons)
cons_del.subscribe(['delivery_topic'])

# %% [markdown]
#  ### 3. Develop Message Filtering Logic 
#
# Develop the logic for each producer to filter messages based on the type field from the JSON data before sending them to the Kafka topic.  Ensure consumers can correctly identify and process only the messages that are
# relevant to them. 4. Submission Guideline:  You are required to submit

# %%
import json as j
import zipfile as z

# Assuming send_inventory_message and send_delivery_message functions are defined

with open('/content/data.json', 'r') as f:
    orders = j.load(f)
    for o in orders:
        if o['type'] == 'inventory':
            send_inv_msg(o)
            print(f"Sent inventory order: {o}")
        elif o['type'] == 'delivery':
            send_del_msg(o)
            print(f"Sent delivery order: {o}")
# Out:
# Sent inventory message: {'order_id': '56', 'product_id': '700', 'quantity': 63, 'type': 'inventory', 'timestamp': '2/22/2024'}
# Sent inventory order: {'order_id': '56', 'product_id': '700', 'quantity': 63, 'type': 'inventory', 'timestamp': '2/22/2024'}
# Sent delivery message: {'order_id': '819', 'product_id': '50', 'quantity': 60, 'type': 'delivery', 'timestamp': '2/14/2024'}
# Sent delivery order: {'order_id': '819', 'product_id': '50', 'quantity': 60, 'type': 'delivery', 'timestamp': '2/14/2024'}
# Sent inventory message: {'order_id': '273', 'product_id': '7', 'quantity': 90, 'type': 'inventory', 'timestamp': '5/9/2023'}
# Sent inventory order: {'order_id': '273', 'product_id': '7', 'quantity': 90, 'type': 'inventory', 'timestamp': '5/9/2023'}
# Sent inventory message: {'order_id': '77591', 'product_id': '11', 'quantity': 18, 'type': 'inventory', 'timestamp': '5/30/2023'}
# Sent inventory order: {'order_id': '77591', 'product_id': '11', 'quantity': 18, 'type': 'inventory', 'timestamp': '5/30/2023'}
# Sent delivery message: {'order_id': '18', 'product_id': '01888', 'quantity': 67, 'type': 'delivery', 'timestamp': '3/30/2024'}
# Sent delivery order: {'order_id': '18', 'product_id': '01888', 'quantity': 67, 'type': 'delivery', 'timestamp': '3/30/2024'}
# Sent delivery message: {'order_id': '4', 'product_id': '264', 'quantity': 16, 'type': 'delivery', 'timestamp': '5/20/2023'}
# Sent delivery order: {'order_id': '4', 'product_id': '264', 'quantity': 16, 'type': 'delivery', 'timestamp': '5/20/2023'}
# Sent delivery message: {'order_id': '189', 'product_id': '92886', 'quantity': 58, 'type': 'delivery', 'timestamp': '12/2/2023'}
# Sent delivery order: {'order_id': '189', 'product_id': '92886', 'quantity': 58, 'type': 'delivery', 'timestamp': '12/2/2023'}
# Sent inventory message: {'order_id': '4', 'product_id': '91221', 'quantity': 16, 'type': 'inventory', 'timestamp': '10/13/2023'}
# Sent inventory order: {'order_id': '4', 'product_id': '91221', 'quantity': 16, 'type': 'inventory', 'timestamp': '10/13/2023'}
# Sent inventory message: {'order_id': '22', 'product_id': '65', 'quantity': 23, 'type': 'inventory', 'timestamp': '1/7/2024'}
# Sent inventory order: {'order_id': '22', 'product_id': '65', 'quantity': 23, 'type': 'inventory', 'timestamp': '1/7/2024'}
# Sent delivery message: {'order_id': '4', 'product_id': '794', 'quantity': 9, 'type': 'delivery', 'timestamp': '5/8/2023'}
# Sent delivery order: {'order_id': '4', 'product_id': '794', 'quantity': 9, 'type': 'delivery', 'timestamp': '5/8/2023'}
# Sent delivery message: {'order_id': '65250', 'product_id': '64', 'quantity': 17, 'type': 'delivery', 'timestamp': '12/7/2023'}
# Sent delivery order: {'order_id': '65250', 'product_id': '64', 'quantity': 17, 'type': 'delivery', 'timestamp': '12/7/2023'}
# Sent delivery message: {'order_id': '96', 'product_id': '9065', 'quantity': 85, 'type': 'delivery', 'timestamp': '2/27/2024'}
# Sent delivery order: {'order_id': '96', 'product_id': '9065', 'quantity': 85, 'type': 'delivery', 'timestamp': '2/27/2024'}
# Sent delivery message: {'order_id': '41', 'product_id': '45247', 'quantity': 7, 'type': 'delivery', 'timestamp': '3/6/2024'}
# Sent delivery order: {'order_id': '41', 'product_id': '45247', 'quantity': 7, 'type': 'delivery', 'timestamp': '3/6/2024'}
# Sent delivery message: {'order_id': '605', 'product_id': '61607', 'quantity': 72, 'type': 'delivery', 'timestamp': '3/4/2024'}
# Sent delivery order: {'order_id': '605', 'product_id': '61607', 'quantity': 72, 'type': 'delivery', 'timestamp': '3/4/2024'}
# Sent delivery message: {'order_id': '2', 'product_id': '45', 'quantity': 28, 'type': 'delivery', 'timestamp': '6/13/2023'}
# Sent delivery order: {'order_id': '2', 'product_id': '45', 'quantity': 28, 'type': 'delivery', 'timestamp': '6/13/2023'}
# Sent delivery message: {'order_id': '4973', 'product_id': '8', 'quantity': 51, 'type': 'delivery', 'timestamp': '2/2/2024'}
# Sent delivery order: {'order_id': '4973', 'product_id': '8', 'quantity': 51, 'type': 'delivery', 'timestamp': '2/2/2024'}
# Sent inventory message: {'order_id': '37', 'product_id': '87079', 'quantity': 57, 'type': 'inventory', 'timestamp': '11/5/2023'}
# Sent inventory order: {'order_id': '37', 'product_id': '87079', 'quantity': 57, 'type': 'inventory', 'timestamp': '11/5/2023'}
# Sent inventory message: {'order_id': '565', 'product_id': '2061', 'quantity': 62, 'type': 'inventory', 'timestamp': '3/10/2024'}
# Sent inventory order: {'order_id': '565', 'product_id': '2061', 'quantity': 62, 'type': 'inventory', 'timestamp': '3/10/2024'}
# Sent inventory message: {'order_id': '939', 'product_id': '34005', 'quantity': 3, 'type': 'inventory', 'timestamp': '12/21/2023'}
# Sent inventory order: {'order_id': '939', 'product_id': '34005', 'quantity': 3, 'type': 'inventory', 'timestamp': '12/21/2023'}
# Sent inventory message: {'order_id': '81092', 'product_id': '6825', 'quantity': 34, 'type': 'inventory', 'timestamp': '3/5/2024'}
# Sent inventory order: {'order_id': '81092', 'product_id': '6825', 'quantity': 34, 'type': 'inventory', 'timestamp': '3/5/2024'}
# Sent delivery message: {'order_id': '84', 'product_id': '1354', 'quantity': 37, 'type': 'delivery', 'timestamp': '11/10/2023'}
# Sent delivery order: {'order_id': '84', 'product_id': '1354', 'quantity': 37, 'type': 'delivery', 'timestamp': '11/10/2023'}
# Sent delivery message: {'order_id': '16', 'product_id': '08', 'quantity': 26, 'type': 'delivery', 'timestamp': '5/1/2023'}
# Sent delivery order: {'order_id': '16', 'product_id': '08', 'quantity': 26, 'type': 'delivery', 'timestamp': '5/1/2023'}
# Sent inventory message: {'order_id': '29', 'product_id': '476', 'quantity': 51, 'type': 'inventory', 'timestamp': '2/13/2024'}
# Sent inventory order: {'order_id': '29', 'product_id': '476', 'quantity': 51, 'type': 'inventory', 'timestamp': '2/13/2024'}
# Sent delivery message: {'order_id': '651', 'product_id': '25', 'quantity': 45, 'type': 'delivery', 'timestamp': '10/11/2023'}
# Sent delivery order: {'order_id': '651', 'product_id': '25', 'quantity': 45, 'type': 'delivery', 'timestamp': '10/11/2023'}
# Sent delivery message: {'order_id': '89649', 'product_id': '5618', 'quantity': 63, 'type': 'delivery', 'timestamp': '8/31/2023'}
# Sent delivery order: {'order_id': '89649', 'product_id': '5618', 'quantity': 63, 'type': 'delivery', 'timestamp': '8/31/2023'}
# Sent inventory message: {'order_id': '126', 'product_id': '41', 'quantity': 30, 'type': 'inventory', 'timestamp': '6/2/2023'}
# Sent inventory order: {'order_id': '126', 'product_id': '41', 'quantity': 30, 'type': 'inventory', 'timestamp': '6/2/2023'}
# Sent inventory message: {'order_id': '09905', 'product_id': '7', 'quantity': 26, 'type': 'inventory', 'timestamp': '5/29/2023'}
# Sent inventory order: {'order_id': '09905', 'product_id': '7', 'quantity': 26, 'type': 'inventory', 'timestamp': '5/29/2023'}
# Sent inventory message: {'order_id': '84', 'product_id': '8931', 'quantity': 76, 'type': 'inventory', 'timestamp': '4/23/2024'}
# Sent inventory order: {'order_id': '84', 'product_id': '8931', 'quantity': 76, 'type': 'inventory', 'timestamp': '4/23/2024'}
# Sent delivery message: {'order_id': '2272', 'product_id': '38', 'quantity': 94, 'type': 'delivery', 'timestamp': '7/19/2023'}
# Sent delivery order: {'order_id': '2272', 'product_id': '38', 'quantity': 94, 'type': 'delivery', 'timestamp': '7/19/2023'}
# Sent delivery message: {'order_id': '157', 'product_id': '564', 'quantity': 55, 'type': 'delivery', 'timestamp': '1/30/2024'}
# Sent delivery order: {'order_id': '157', 'product_id': '564', 'quantity': 55, 'type': 'delivery', 'timestamp': '1/30/2024'}
# Sent inventory message: {'order_id': '407', 'product_id': '4', 'quantity': 41, 'type': 'inventory', 'timestamp': '2/22/2024'}
# Sent inventory order: {'order_id': '407', 'product_id': '4', 'quantity': 41, 'type': 'inventory', 'timestamp': '2/22/2024'}
# Sent delivery message: {'order_id': '73345', 'product_id': '7', 'quantity': 80, 'type': 'delivery', 'timestamp': '11/16/2023'}
# Sent delivery order: {'order_id': '73345', 'product_id': '7', 'quantity': 80, 'type': 'delivery', 'timestamp': '11/16/2023'}
# Sent inventory message: {'order_id': '88835', 'product_id': '81', 'quantity': 2, 'type': 'inventory', 'timestamp': '8/19/2023'}
# Sent inventory order: {'order_id': '88835', 'product_id': '81', 'quantity': 2, 'type': 'inventory', 'timestamp': '8/19/2023'}
# Sent delivery message: {'order_id': '34', 'product_id': '44827', 'quantity': 51, 'type': 'delivery', 'timestamp': '4/18/2024'}
# Sent delivery order: {'order_id': '34', 'product_id': '44827', 'quantity': 51, 'type': 'delivery', 'timestamp': '4/18/2024'}
# Sent delivery message: {'order_id': '766', 'product_id': '69', 'quantity': 86, 'type': 'delivery', 'timestamp': '6/16/2023'}
# Sent delivery order: {'order_id': '766', 'product_id': '69', 'quantity': 86, 'type': 'delivery', 'timestamp': '6/16/2023'}
# Sent inventory message: {'order_id': '296', 'product_id': '8174', 'quantity': 82, 'type': 'inventory', 'timestamp': '3/2/2024'}
# Sent inventory order: {'order_id': '296', 'product_id': '8174', 'quantity': 82, 'type': 'inventory', 'timestamp': '3/2/2024'}
# Sent delivery message: {'order_id': '27116', 'product_id': '91', 'quantity': 75, 'type': 'delivery', 'timestamp': '1/19/2024'}
# Sent delivery order: {'order_id': '27116', 'product_id': '91', 'quantity': 75, 'type': 'delivery', 'timestamp': '1/19/2024'}
# Sent inventory message: {'order_id': '7526', 'product_id': '13', 'quantity': 87, 'type': 'inventory', 'timestamp': '7/8/2023'}
# Sent inventory order: {'order_id': '7526', 'product_id': '13', 'quantity': 87, 'type': 'inventory', 'timestamp': '7/8/2023'}
# Sent delivery message: {'order_id': '29', 'product_id': '2', 'quantity': 88, 'type': 'delivery', 'timestamp': '3/12/2024'}
# Sent delivery order: {'order_id': '29', 'product_id': '2', 'quantity': 88, 'type': 'delivery', 'timestamp': '3/12/2024'}
# Sent delivery message: {'order_id': '7', 'product_id': '13', 'quantity': 7, 'type': 'delivery', 'timestamp': '5/18/2023'}
# Sent delivery order: {'order_id': '7', 'product_id': '13', 'quantity': 7, 'type': 'delivery', 'timestamp': '5/18/2023'}
# Sent delivery message: {'order_id': '401', 'product_id': '7', 'quantity': 19, 'type': 'delivery', 'timestamp': '5/1/2023'}
# Sent delivery order: {'order_id': '401', 'product_id': '7', 'quantity': 19, 'type': 'delivery', 'timestamp': '5/1/2023'}
# Sent inventory message: {'order_id': '5', 'product_id': '0', 'quantity': 62, 'type': 'inventory', 'timestamp': '3/5/2024'}
# Sent inventory order: {'order_id': '5', 'product_id': '0', 'quantity': 62, 'type': 'inventory', 'timestamp': '3/5/2024'}
# Sent inventory message: {'order_id': '7141', 'product_id': '504', 'quantity': 50, 'type': 'inventory', 'timestamp': '5/5/2023'}
# Sent inventory order: {'order_id': '7141', 'product_id': '504', 'quantity': 50, 'type': 'inventory', 'timestamp': '5/5/2023'}
# Sent inventory message: {'order_id': '06368', 'product_id': '92', 'quantity': 58, 'type': 'inventory', 'timestamp': '11/11/2023'}
# Sent inventory order: {'order_id': '06368', 'product_id': '92', 'quantity': 58, 'type': 'inventory', 'timestamp': '11/11/2023'}
# Sent delivery message: {'order_id': '864', 'product_id': '6', 'quantity': 17, 'type': 'delivery', 'timestamp': '11/16/2023'}
# Sent delivery order: {'order_id': '864', 'product_id': '6', 'quantity': 17, 'type': 'delivery', 'timestamp': '11/16/2023'}
# Sent inventory message: {'order_id': '790', 'product_id': '877', 'quantity': 69, 'type': 'inventory', 'timestamp': '1/13/2024'}
# Sent inventory order: {'order_id': '790', 'product_id': '877', 'quantity': 69, 'type': 'inventory', 'timestamp': '1/13/2024'}
# Sent inventory message: {'order_id': '421', 'product_id': '671', 'quantity': 71, 'type': 'inventory', 'timestamp': '8/20/2023'}
# Sent inventory order: {'order_id': '421', 'product_id': '671', 'quantity': 71, 'type': 'inventory', 'timestamp': '8/20/2023'}
# Sent inventory message: {'order_id': '6781', 'product_id': '6', 'quantity': 61, 'type': 'inventory', 'timestamp': '2/18/2024'}
# Sent inventory order: {'order_id': '6781', 'product_id': '6', 'quantity': 61, 'type': 'inventory', 'timestamp': '2/18/2024'}
# Sent delivery message: {'order_id': '910', 'product_id': '5378', 'quantity': 18, 'type': 'delivery', 'timestamp': '3/7/2024'}
# Sent delivery order: {'order_id': '910', 'product_id': '5378', 'quantity': 18, 'type': 'delivery', 'timestamp': '3/7/2024'}
# Sent delivery message: {'order_id': '73', 'product_id': '125', 'quantity': 39, 'type': 'delivery', 'timestamp': '12/21/2023'}
# Sent delivery order: {'order_id': '73', 'product_id': '125', 'quantity': 39, 'type': 'delivery', 'timestamp': '12/21/2023'}
# Sent inventory message: {'order_id': '8125', 'product_id': '6422', 'quantity': 7, 'type': 'inventory', 'timestamp': '1/17/2024'}
# Sent inventory order: {'order_id': '8125', 'product_id': '6422', 'quantity': 7, 'type': 'inventory', 'timestamp': '1/17/2024'}
# Sent inventory message: {'order_id': '97835', 'product_id': '558', 'quantity': 70, 'type': 'inventory', 'timestamp': '5/25/2023'}
# Sent inventory order: {'order_id': '97835', 'product_id': '558', 'quantity': 70, 'type': 'inventory', 'timestamp': '5/25/2023'}
# Sent inventory message: {'order_id': '1825', 'product_id': '73', 'quantity': 58, 'type': 'inventory', 'timestamp': '10/25/2023'}
# Sent inventory order: {'order_id': '1825', 'product_id': '73', 'quantity': 58, 'type': 'inventory', 'timestamp': '10/25/2023'}
# Sent inventory message: {'order_id': '674', 'product_id': '99', 'quantity': 30, 'type': 'inventory', 'timestamp': '8/8/2023'}
# Sent inventory order: {'order_id': '674', 'product_id': '99', 'quantity': 30, 'type': 'inventory', 'timestamp': '8/8/2023'}
# Sent delivery message: {'order_id': '49', 'product_id': '44783', 'quantity': 79, 'type': 'delivery', 'timestamp': '6/14/2023'}
# Sent delivery order: {'order_id': '49', 'product_id': '44783', 'quantity': 79, 'type': 'delivery', 'timestamp': '6/14/2023'}
# Sent inventory message: {'order_id': '8', 'product_id': '8', 'quantity': 8, 'type': 'inventory', 'timestamp': '9/6/2023'}
# Sent inventory order: {'order_id': '8', 'product_id': '8', 'quantity': 8, 'type': 'inventory', 'timestamp': '9/6/2023'}
# Sent delivery message: {'order_id': '67', 'product_id': '36', 'quantity': 33, 'type': 'delivery', 'timestamp': '6/18/2023'}
# Sent delivery order: {'order_id': '67', 'product_id': '36', 'quantity': 33, 'type': 'delivery', 'timestamp': '6/18/2023'}
# Sent inventory message: {'order_id': '3', 'product_id': '59889', 'quantity': 46, 'type': 'inventory', 'timestamp': '5/31/2023'}
# Sent inventory order: {'order_id': '3', 'product_id': '59889', 'quantity': 46, 'type': 'inventory', 'timestamp': '5/31/2023'}
# Sent inventory message: {'order_id': '1', 'product_id': '5', 'quantity': 13, 'type': 'inventory', 'timestamp': '3/6/2024'}
# Sent inventory order: {'order_id': '1', 'product_id': '5', 'quantity': 13, 'type': 'inventory', 'timestamp': '3/6/2024'}
# Sent delivery message: {'order_id': '80757', 'product_id': '769', 'quantity': 19, 'type': 'delivery', 'timestamp': '9/7/2023'}
# Sent delivery order: {'order_id': '80757', 'product_id': '769', 'quantity': 19, 'type': 'delivery', 'timestamp': '9/7/2023'}
# Sent delivery message: {'order_id': '5', 'product_id': '242', 'quantity': 13, 'type': 'delivery', 'timestamp': '8/28/2023'}
# Sent delivery order: {'order_id': '5', 'product_id': '242', 'quantity': 13, 'type': 'delivery', 'timestamp': '8/28/2023'}
# Sent delivery message: {'order_id': '7716', 'product_id': '585', 'quantity': 13, 'type': 'delivery', 'timestamp': '4/8/2024'}
# Sent delivery order: {'order_id': '7716', 'product_id': '585', 'quantity': 13, 'type': 'delivery', 'timestamp': '4/8/2024'}
# Sent inventory message: {'order_id': '88152', 'product_id': '317', 'quantity': 86, 'type': 'inventory', 'timestamp': '6/4/2023'}
# Sent inventory order: {'order_id': '88152', 'product_id': '317', 'quantity': 86, 'type': 'inventory', 'timestamp': '6/4/2023'}
# Sent delivery message: {'order_id': '8514', 'product_id': '41', 'quantity': 36, 'type': 'delivery', 'timestamp': '1/18/2024'}
# Sent delivery order: {'order_id': '8514', 'product_id': '41', 'quantity': 36, 'type': 'delivery', 'timestamp': '1/18/2024'}
# Sent inventory message: {'order_id': '7580', 'product_id': '7', 'quantity': 86, 'type': 'inventory', 'timestamp': '2/2/2024'}
# Sent inventory order: {'order_id': '7580', 'product_id': '7', 'quantity': 86, 'type': 'inventory', 'timestamp': '2/2/2024'}
# Sent inventory message: {'order_id': '361', 'product_id': '90', 'quantity': 66, 'type': 'inventory', 'timestamp': '7/20/2023'}
# Sent inventory order: {'order_id': '361', 'product_id': '90', 'quantity': 66, 'type': 'inventory', 'timestamp': '7/20/2023'}
# Sent delivery message: {'order_id': '41562', 'product_id': '38', 'quantity': 50, 'type': 'delivery', 'timestamp': '10/3/2023'}
# Sent delivery order: {'order_id': '41562', 'product_id': '38', 'quantity': 50, 'type': 'delivery', 'timestamp': '10/3/2023'}
# Sent inventory message: {'order_id': '75260', 'product_id': '63', 'quantity': 65, 'type': 'inventory', 'timestamp': '2/7/2024'}
# Sent inventory order: {'order_id': '75260', 'product_id': '63', 'quantity': 65, 'type': 'inventory', 'timestamp': '2/7/2024'}
# Sent inventory message: {'order_id': '10311', 'product_id': '44', 'quantity': 25, 'type': 'inventory', 'timestamp': '9/3/2023'}
# Sent inventory order: {'order_id': '10311', 'product_id': '44', 'quantity': 25, 'type': 'inventory', 'timestamp': '9/3/2023'}
# Sent delivery message: {'order_id': '76', 'product_id': '26', 'quantity': 65, 'type': 'delivery', 'timestamp': '5/30/2023'}
# Sent delivery order: {'order_id': '76', 'product_id': '26', 'quantity': 65, 'type': 'delivery', 'timestamp': '5/30/2023'}
# Sent delivery message: {'order_id': '7125', 'product_id': '737', 'quantity': 100, 'type': 'delivery', 'timestamp': '6/18/2023'}
# Sent delivery order: {'order_id': '7125', 'product_id': '737', 'quantity': 100, 'type': 'delivery', 'timestamp': '6/18/2023'}
# Sent inventory message: {'order_id': '308', 'product_id': '7', 'quantity': 74, 'type': 'inventory', 'timestamp': '6/27/2023'}
# Sent inventory order: {'order_id': '308', 'product_id': '7', 'quantity': 74, 'type': 'inventory', 'timestamp': '6/27/2023'}
# Sent delivery message: {'order_id': '8', 'product_id': '64345', 'quantity': 55, 'type': 'delivery', 'timestamp': '10/19/2023'}
# Sent delivery order: {'order_id': '8', 'product_id': '64345', 'quantity': 55, 'type': 'delivery', 'timestamp': '10/19/2023'}
# Sent inventory message: {'order_id': '4943', 'product_id': '7442', 'quantity': 43, 'type': 'inventory', 'timestamp': '10/19/2023'}
# Sent inventory order: {'order_id': '4943', 'product_id': '7442', 'quantity': 43, 'type': 'inventory', 'timestamp': '10/19/2023'}
# Sent inventory message: {'order_id': '499', 'product_id': '1', 'quantity': 94, 'type': 'inventory', 'timestamp': '7/29/2023'}
# Sent inventory order: {'order_id': '499', 'product_id': '1', 'quantity': 94, 'type': 'inventory', 'timestamp': '7/29/2023'}
# Sent inventory message: {'order_id': '764', 'product_id': '9306', 'quantity': 7, 'type': 'inventory', 'timestamp': '9/11/2023'}
# Sent inventory order: {'order_id': '764', 'product_id': '9306', 'quantity': 7, 'type': 'inventory', 'timestamp': '9/11/2023'}
# Sent inventory message: {'order_id': '59493', 'product_id': '0', 'quantity': 94, 'type': 'inventory', 'timestamp': '12/30/2023'}
# Sent inventory order: {'order_id': '59493', 'product_id': '0', 'quantity': 94, 'type': 'inventory', 'timestamp': '12/30/2023'}
# Sent inventory message: {'order_id': '12324', 'product_id': '8', 'quantity': 23, 'type': 'inventory', 'timestamp': '4/1/2024'}
# Sent inventory order: {'order_id': '12324', 'product_id': '8', 'quantity': 23, 'type': 'inventory', 'timestamp': '4/1/2024'}
# Sent inventory message: {'order_id': '541', 'product_id': '98', 'quantity': 87, 'type': 'inventory', 'timestamp': '7/29/2023'}
# Sent inventory order: {'order_id': '541', 'product_id': '98', 'quantity': 87, 'type': 'inventory', 'timestamp': '7/29/2023'}
# Sent inventory message: {'order_id': '86', 'product_id': '50509', 'quantity': 42, 'type': 'inventory', 'timestamp': '3/15/2024'}
# Sent inventory order: {'order_id': '86', 'product_id': '50509', 'quantity': 42, 'type': 'inventory', 'timestamp': '3/15/2024'}
# Sent delivery message: {'order_id': '2', 'product_id': '74377', 'quantity': 54, 'type': 'delivery', 'timestamp': '12/11/2023'}
# Sent delivery order: {'order_id': '2', 'product_id': '74377', 'quantity': 54, 'type': 'delivery', 'timestamp': '12/11/2023'}
# Sent delivery message: {'order_id': '769', 'product_id': '5528', 'quantity': 66, 'type': 'delivery', 'timestamp': '3/5/2024'}
# Sent delivery order: {'order_id': '769', 'product_id': '5528', 'quantity': 66, 'type': 'delivery', 'timestamp': '3/5/2024'}
# Sent delivery message: {'order_id': '127', 'product_id': '905', 'quantity': 75, 'type': 'delivery', 'timestamp': '4/6/2024'}
# Sent delivery order: {'order_id': '127', 'product_id': '905', 'quantity': 75, 'type': 'delivery', 'timestamp': '4/6/2024'}
# Sent inventory message: {'order_id': '2', 'product_id': '31864', 'quantity': 89, 'type': 'inventory', 'timestamp': '10/2/2023'}
# Sent inventory order: {'order_id': '2', 'product_id': '31864', 'quantity': 89, 'type': 'inventory', 'timestamp': '10/2/2023'}
# Sent inventory message: {'order_id': '5897', 'product_id': '65', 'quantity': 47, 'type': 'inventory', 'timestamp': '1/4/2024'}
# Sent inventory order: {'order_id': '5897', 'product_id': '65', 'quantity': 47, 'type': 'inventory', 'timestamp': '1/4/2024'}
# Sent inventory message: {'order_id': '2', 'product_id': '2216', 'quantity': 58, 'type': 'inventory', 'timestamp': '4/1/2024'}
# Sent inventory order: {'order_id': '2', 'product_id': '2216', 'quantity': 58, 'type': 'inventory', 'timestamp': '4/1/2024'}
# Sent inventory message: {'order_id': '32', 'product_id': '258', 'quantity': 90, 'type': 'inventory', 'timestamp': '10/10/2023'}
# Sent inventory order: {'order_id': '32', 'product_id': '258', 'quantity': 90, 'type': 'inventory', 'timestamp': '10/10/2023'}
# Sent inventory message: {'order_id': '305', 'product_id': '21395', 'quantity': 10, 'type': 'inventory', 'timestamp': '6/29/2023'}
# Sent inventory order: {'order_id': '305', 'product_id': '21395', 'quantity': 10, 'type': 'inventory', 'timestamp': '6/29/2023'}
# Sent inventory message: {'order_id': '6', 'product_id': '586', 'quantity': 70, 'type': 'inventory', 'timestamp': '5/6/2023'}
# Sent inventory order: {'order_id': '6', 'product_id': '586', 'quantity': 70, 'type': 'inventory', 'timestamp': '5/6/2023'}
# Sent delivery message: {'order_id': '91', 'product_id': '1866', 'quantity': 40, 'type': 'delivery', 'timestamp': '9/22/2023'}
# Sent delivery order: {'order_id': '91', 'product_id': '1866', 'quantity': 40, 'type': 'delivery', 'timestamp': '9/22/2023'}
# Sent delivery message: {'order_id': '33', 'product_id': '0', 'quantity': 71, 'type': 'delivery', 'timestamp': '3/28/2024'}
# Sent delivery order: {'order_id': '33', 'product_id': '0', 'quantity': 71, 'type': 'delivery', 'timestamp': '3/28/2024'}
# Sent inventory message: {'order_id': '2043', 'product_id': '6', 'quantity': 9, 'type': 'inventory', 'timestamp': '8/9/2023'}
# Sent inventory order: {'order_id': '2043', 'product_id': '6', 'quantity': 9, 'type': 'inventory', 'timestamp': '8/9/2023'}
# Sent inventory message: {'order_id': '284', 'product_id': '33829', 'quantity': 71, 'type': 'inventory', 'timestamp': '4/25/2024'}
# Sent inventory order: {'order_id': '284', 'product_id': '33829', 'quantity': 71, 'type': 'inventory', 'timestamp': '4/25/2024'}
# Sent delivery message: {'order_id': '864', 'product_id': '0', 'quantity': 99, 'type': 'delivery', 'timestamp': '10/18/2023'}
# Sent delivery order: {'order_id': '864', 'product_id': '0', 'quantity': 99, 'type': 'delivery', 'timestamp': '10/18/2023'}
# Sent inventory message: {'order_id': '0', 'product_id': '2312', 'quantity': 36, 'type': 'inventory', 'timestamp': '5/11/2023'}
# Sent inventory order: {'order_id': '0', 'product_id': '2312', 'quantity': 36, 'type': 'inventory', 'timestamp': '5/11/2023'}
# Sent inventory message: {'order_id': '6762', 'product_id': '527', 'quantity': 69, 'type': 'inventory', 'timestamp': '7/22/2023'}
# Sent inventory order: {'order_id': '6762', 'product_id': '527', 'quantity': 69, 'type': 'inventory', 'timestamp': '7/22/2023'}
# Sent delivery message: {'order_id': '031', 'product_id': '63393', 'quantity': 40, 'type': 'delivery', 'timestamp': '8/19/2023'}
# Sent delivery order: {'order_id': '031', 'product_id': '63393', 'quantity': 40, 'type': 'delivery', 'timestamp': '8/19/2023'}
# Sent inventory message: {'order_id': '537', 'product_id': '7904', 'quantity': 99, 'type': 'inventory', 'timestamp': '10/27/2023'}
# Sent inventory order: {'order_id': '537', 'product_id': '7904', 'quantity': 99, 'type': 'inventory', 'timestamp': '10/27/2023'}
# Sent inventory message: {'order_id': '72639', 'product_id': '12904', 'quantity': 80, 'type': 'inventory', 'timestamp': '4/10/2024'}
# Sent inventory order: {'order_id': '72639', 'product_id': '12904', 'quantity': 80, 'type': 'inventory', 'timestamp': '4/10/2024'}
# Sent inventory message: {'order_id': '47', 'product_id': '87835', 'quantity': 73, 'type': 'inventory', 'timestamp': '1/17/2024'}
# Sent inventory order: {'order_id': '47', 'product_id': '87835', 'quantity': 73, 'type': 'inventory', 'timestamp': '1/17/2024'}
# Sent delivery message: {'order_id': '53', 'product_id': '6', 'quantity': 54, 'type': 'delivery', 'timestamp': '3/30/2024'}
# Sent delivery order: {'order_id': '53', 'product_id': '6', 'quantity': 54, 'type': 'delivery', 'timestamp': '3/30/2024'}
# Sent inventory message: {'order_id': '0847', 'product_id': '0', 'quantity': 71, 'type': 'inventory', 'timestamp': '3/19/2024'}
# Sent inventory order: {'order_id': '0847', 'product_id': '0', 'quantity': 71, 'type': 'inventory', 'timestamp': '3/19/2024'}
# Sent delivery message: {'order_id': '3', 'product_id': '2', 'quantity': 64, 'type': 'delivery', 'timestamp': '6/15/2023'}
# Sent delivery order: {'order_id': '3', 'product_id': '2', 'quantity': 64, 'type': 'delivery', 'timestamp': '6/15/2023'}
# Sent inventory message: {'order_id': '95', 'product_id': '2', 'quantity': 43, 'type': 'inventory', 'timestamp': '11/14/2023'}
# Sent inventory order: {'order_id': '95', 'product_id': '2', 'quantity': 43, 'type': 'inventory', 'timestamp': '11/14/2023'}
# Sent delivery message: {'order_id': '6926', 'product_id': '24863', 'quantity': 25, 'type': 'delivery', 'timestamp': '7/2/2023'}
# Sent delivery order: {'order_id': '6926', 'product_id': '24863', 'quantity': 25, 'type': 'delivery', 'timestamp': '7/2/2023'}
# Sent inventory message: {'order_id': '09337', 'product_id': '4283', 'quantity': 39, 'type': 'inventory', 'timestamp': '10/6/2023'}
# Sent inventory order: {'order_id': '09337', 'product_id': '4283', 'quantity': 39, 'type': 'inventory', 'timestamp': '10/6/2023'}
# Sent inventory message: {'order_id': '2', 'product_id': '2952', 'quantity': 33, 'type': 'inventory', 'timestamp': '10/28/2023'}
# Sent inventory order: {'order_id': '2', 'product_id': '2952', 'quantity': 33, 'type': 'inventory', 'timestamp': '10/28/2023'}
# Sent delivery message: {'order_id': '4433', 'product_id': '133', 'quantity': 97, 'type': 'delivery', 'timestamp': '2/16/2024'}
# Sent delivery order: {'order_id': '4433', 'product_id': '133', 'quantity': 97, 'type': 'delivery', 'timestamp': '2/16/2024'}
# Sent delivery message: {'order_id': '82', 'product_id': '702', 'quantity': 40, 'type': 'delivery', 'timestamp': '12/5/2023'}
# Sent delivery order: {'order_id': '82', 'product_id': '702', 'quantity': 40, 'type': 'delivery', 'timestamp': '12/5/2023'}
# Sent inventory message: {'order_id': '2', 'product_id': '016', 'quantity': 88, 'type': 'inventory', 'timestamp': '6/24/2023'}
# Sent inventory order: {'order_id': '2', 'product_id': '016', 'quantity': 88, 'type': 'inventory', 'timestamp': '6/24/2023'}
# Sent delivery message: {'order_id': '747', 'product_id': '1', 'quantity': 77, 'type': 'delivery', 'timestamp': '5/6/2023'}
# Sent delivery order: {'order_id': '747', 'product_id': '1', 'quantity': 77, 'type': 'delivery', 'timestamp': '5/6/2023'}
# Sent delivery message: {'order_id': '8886', 'product_id': '308', 'quantity': 11, 'type': 'delivery', 'timestamp': '1/28/2024'}
# Sent delivery order: {'order_id': '8886', 'product_id': '308', 'quantity': 11, 'type': 'delivery', 'timestamp': '1/28/2024'}
# Sent inventory message: {'order_id': '9', 'product_id': '7', 'quantity': 66, 'type': 'inventory', 'timestamp': '7/28/2023'}
# Sent inventory order: {'order_id': '9', 'product_id': '7', 'quantity': 66, 'type': 'inventory', 'timestamp': '7/28/2023'}
# Sent inventory message: {'order_id': '59793', 'product_id': '643', 'quantity': 39, 'type': 'inventory', 'timestamp': '12/11/2023'}
# Sent inventory order: {'order_id': '59793', 'product_id': '643', 'quantity': 39, 'type': 'inventory', 'timestamp': '12/11/2023'}
# Sent inventory message: {'order_id': '40', 'product_id': '620', 'quantity': 63, 'type': 'inventory', 'timestamp': '10/27/2023'}
# Sent inventory order: {'order_id': '40', 'product_id': '620', 'quantity': 63, 'type': 'inventory', 'timestamp': '10/27/2023'}
# Sent delivery message: {'order_id': '3', 'product_id': '4670', 'quantity': 98, 'type': 'delivery', 'timestamp': '5/7/2023'}
# Sent delivery order: {'order_id': '3', 'product_id': '4670', 'quantity': 98, 'type': 'delivery', 'timestamp': '5/7/2023'}
# Sent delivery message: {'order_id': '9432', 'product_id': '91418', 'quantity': 37, 'type': 'delivery', 'timestamp': '3/6/2024'}
# Sent delivery order: {'order_id': '9432', 'product_id': '91418', 'quantity': 37, 'type': 'delivery', 'timestamp': '3/6/2024'}
# Sent delivery message: {'order_id': '87', 'product_id': '719', 'quantity': 69, 'type': 'delivery', 'timestamp': '2/6/2024'}
# Sent delivery order: {'order_id': '87', 'product_id': '719', 'quantity': 69, 'type': 'delivery', 'timestamp': '2/6/2024'}
# Sent delivery message: {'order_id': '54375', 'product_id': '450', 'quantity': 24, 'type': 'delivery', 'timestamp': '7/2/2023'}
# Sent delivery order: {'order_id': '54375', 'product_id': '450', 'quantity': 24, 'type': 'delivery', 'timestamp': '7/2/2023'}
# Sent inventory message: {'order_id': '7225', 'product_id': '4', 'quantity': 86, 'type': 'inventory', 'timestamp': '12/11/2023'}
# Sent inventory order: {'order_id': '7225', 'product_id': '4', 'quantity': 86, 'type': 'inventory', 'timestamp': '12/11/2023'}
# Sent inventory message: {'order_id': '72', 'product_id': '4656', 'quantity': 97, 'type': 'inventory', 'timestamp': '4/26/2023'}
# Sent inventory order: {'order_id': '72', 'product_id': '4656', 'quantity': 97, 'type': 'inventory', 'timestamp': '4/26/2023'}
# Sent inventory message: {'order_id': '36', 'product_id': '6268', 'quantity': 98, 'type': 'inventory', 'timestamp': '1/15/2024'}
# Sent inventory order: {'order_id': '36', 'product_id': '6268', 'quantity': 98, 'type': 'inventory', 'timestamp': '1/15/2024'}
# Sent delivery message: {'order_id': '24', 'product_id': '36629', 'quantity': 46, 'type': 'delivery', 'timestamp': '5/31/2023'}
# Sent delivery order: {'order_id': '24', 'product_id': '36629', 'quantity': 46, 'type': 'delivery', 'timestamp': '5/31/2023'}
# Sent delivery message: {'order_id': '95737', 'product_id': '9', 'quantity': 95, 'type': 'delivery', 'timestamp': '7/17/2023'}
# Sent delivery order: {'order_id': '95737', 'product_id': '9', 'quantity': 95, 'type': 'delivery', 'timestamp': '7/17/2023'}
# Sent delivery message: {'order_id': '18', 'product_id': '6783', 'quantity': 78, 'type': 'delivery', 'timestamp': '2/10/2024'}
# Sent delivery order: {'order_id': '18', 'product_id': '6783', 'quantity': 78, 'type': 'delivery', 'timestamp': '2/10/2024'}
# Sent delivery message: {'order_id': '43464', 'product_id': '652', 'quantity': 62, 'type': 'delivery', 'timestamp': '1/6/2024'}
# Sent delivery order: {'order_id': '43464', 'product_id': '652', 'quantity': 62, 'type': 'delivery', 'timestamp': '1/6/2024'}
# Sent delivery message: {'order_id': '29', 'product_id': '70', 'quantity': 1, 'type': 'delivery', 'timestamp': '11/11/2023'}
# Sent delivery order: {'order_id': '29', 'product_id': '70', 'quantity': 1, 'type': 'delivery', 'timestamp': '11/11/2023'}
# Sent delivery message: {'order_id': '8', 'product_id': '41', 'quantity': 97, 'type': 'delivery', 'timestamp': '1/22/2024'}
# Sent delivery order: {'order_id': '8', 'product_id': '41', 'quantity': 97, 'type': 'delivery', 'timestamp': '1/22/2024'}
# Sent inventory message: {'order_id': '401', 'product_id': '0', 'quantity': 95, 'type': 'inventory', 'timestamp': '6/24/2023'}
# Sent inventory order: {'order_id': '401', 'product_id': '0', 'quantity': 95, 'type': 'inventory', 'timestamp': '6/24/2023'}
# Sent inventory message: {'order_id': '511', 'product_id': '373', 'quantity': 31, 'type': 'inventory', 'timestamp': '2/13/2024'}
# Sent inventory order: {'order_id': '511', 'product_id': '373', 'quantity': 31, 'type': 'inventory', 'timestamp': '2/13/2024'}
# Sent inventory message: {'order_id': '1', 'product_id': '83065', 'quantity': 75, 'type': 'inventory', 'timestamp': '7/9/2023'}
# Sent inventory order: {'order_id': '1', 'product_id': '83065', 'quantity': 75, 'type': 'inventory', 'timestamp': '7/9/2023'}
# Sent delivery message: {'order_id': '20653', 'product_id': '2', 'quantity': 5, 'type': 'delivery', 'timestamp': '1/18/2024'}
# Sent delivery order: {'order_id': '20653', 'product_id': '2', 'quantity': 5, 'type': 'delivery', 'timestamp': '1/18/2024'}
# Sent inventory message: {'order_id': '5', 'product_id': '2041', 'quantity': 57, 'type': 'inventory', 'timestamp': '5/23/2023'}
# Sent inventory order: {'order_id': '5', 'product_id': '2041', 'quantity': 57, 'type': 'inventory', 'timestamp': '5/23/2023'}
# Sent inventory message: {'order_id': '08', 'product_id': '18', 'quantity': 87, 'type': 'inventory', 'timestamp': '4/4/2024'}
# Sent inventory order: {'order_id': '08', 'product_id': '18', 'quantity': 87, 'type': 'inventory', 'timestamp': '4/4/2024'}
# Sent delivery message: {'order_id': '23', 'product_id': '1', 'quantity': 83, 'type': 'delivery', 'timestamp': '1/22/2024'}
# Sent delivery order: {'order_id': '23', 'product_id': '1', 'quantity': 83, 'type': 'delivery', 'timestamp': '1/22/2024'}
# Sent delivery message: {'order_id': '46357', 'product_id': '6384', 'quantity': 49, 'type': 'delivery', 'timestamp': '9/3/2023'}
# Sent delivery order: {'order_id': '46357', 'product_id': '6384', 'quantity': 49, 'type': 'delivery', 'timestamp': '9/3/2023'}
# Sent inventory message: {'order_id': '66707', 'product_id': '4020', 'quantity': 85, 'type': 'inventory', 'timestamp': '3/23/2024'}
# Sent inventory order: {'order_id': '66707', 'product_id': '4020', 'quantity': 85, 'type': 'inventory', 'timestamp': '3/23/2024'}
# Sent delivery message: {'order_id': '8', 'product_id': '8556', 'quantity': 15, 'type': 'delivery', 'timestamp': '10/10/2023'}
# Sent delivery order: {'order_id': '8', 'product_id': '8556', 'quantity': 15, 'type': 'delivery', 'timestamp': '10/10/2023'}
# Sent inventory message: {'order_id': '473', 'product_id': '0', 'quantity': 50, 'type': 'inventory', 'timestamp': '1/29/2024'}
# Sent inventory order: {'order_id': '473', 'product_id': '0', 'quantity': 50, 'type': 'inventory', 'timestamp': '1/29/2024'}
# Sent inventory message: {'order_id': '9621', 'product_id': '0770', 'quantity': 93, 'type': 'inventory', 'timestamp': '3/1/2024'}
# Sent inventory order: {'order_id': '9621', 'product_id': '0770', 'quantity': 93, 'type': 'inventory', 'timestamp': '3/1/2024'}
# Sent delivery message: {'order_id': '462', 'product_id': '64076', 'quantity': 26, 'type': 'delivery', 'timestamp': '6/13/2023'}
# Sent delivery order: {'order_id': '462', 'product_id': '64076', 'quantity': 26, 'type': 'delivery', 'timestamp': '6/13/2023'}
# Sent inventory message: {'order_id': '6', 'product_id': '0', 'quantity': 74, 'type': 'inventory', 'timestamp': '11/18/2023'}
# Sent inventory order: {'order_id': '6', 'product_id': '0', 'quantity': 74, 'type': 'inventory', 'timestamp': '11/18/2023'}
# Sent inventory message: {'order_id': '38888', 'product_id': '38224', 'quantity': 7, 'type': 'inventory', 'timestamp': '12/19/2023'}
# Sent inventory order: {'order_id': '38888', 'product_id': '38224', 'quantity': 7, 'type': 'inventory', 'timestamp': '12/19/2023'}
# Sent inventory message: {'order_id': '6', 'product_id': '3825', 'quantity': 6, 'type': 'inventory', 'timestamp': '1/25/2024'}
# Sent inventory order: {'order_id': '6', 'product_id': '3825', 'quantity': 6, 'type': 'inventory', 'timestamp': '1/25/2024'}
# Sent inventory message: {'order_id': '3624', 'product_id': '9', 'quantity': 81, 'type': 'inventory', 'timestamp': '5/26/2023'}
# Sent inventory order: {'order_id': '3624', 'product_id': '9', 'quantity': 81, 'type': 'inventory', 'timestamp': '5/26/2023'}
# Sent inventory message: {'order_id': '68', 'product_id': '8146', 'quantity': 27, 'type': 'inventory', 'timestamp': '2/10/2024'}
# Sent inventory order: {'order_id': '68', 'product_id': '8146', 'quantity': 27, 'type': 'inventory', 'timestamp': '2/10/2024'}
# Sent inventory message: {'order_id': '8806', 'product_id': '43696', 'quantity': 55, 'type': 'inventory', 'timestamp': '3/28/2024'}
# Sent inventory order: {'order_id': '8806', 'product_id': '43696', 'quantity': 55, 'type': 'inventory', 'timestamp': '3/28/2024'}
# Sent delivery message: {'order_id': '8', 'product_id': '7744', 'quantity': 26, 'type': 'delivery', 'timestamp': '4/23/2024'}
# Sent delivery order: {'order_id': '8', 'product_id': '7744', 'quantity': 26, 'type': 'delivery', 'timestamp': '4/23/2024'}
# Sent delivery message: {'order_id': '852', 'product_id': '6', 'quantity': 97, 'type': 'delivery', 'timestamp': '11/16/2023'}
# Sent delivery order: {'order_id': '852', 'product_id': '6', 'quantity': 97, 'type': 'delivery', 'timestamp': '11/16/2023'}
# Sent inventory message: {'order_id': '39', 'product_id': '550', 'quantity': 58, 'type': 'inventory', 'timestamp': '1/18/2024'}
# Sent inventory order: {'order_id': '39', 'product_id': '550', 'quantity': 58, 'type': 'inventory', 'timestamp': '1/18/2024'}
# Sent inventory message: {'order_id': '98', 'product_id': '717', 'quantity': 7, 'type': 'inventory', 'timestamp': '5/10/2023'}
# Sent inventory order: {'order_id': '98', 'product_id': '717', 'quantity': 7, 'type': 'inventory', 'timestamp': '5/10/2023'}
# Sent inventory message: {'order_id': '73952', 'product_id': '0', 'quantity': 90, 'type': 'inventory', 'timestamp': '3/3/2024'}
# Sent inventory order: {'order_id': '73952', 'product_id': '0', 'quantity': 90, 'type': 'inventory', 'timestamp': '3/3/2024'}
# Sent inventory message: {'order_id': '48424', 'product_id': '628', 'quantity': 35, 'type': 'inventory', 'timestamp': '6/14/2023'}
# Sent inventory order: {'order_id': '48424', 'product_id': '628', 'quantity': 35, 'type': 'inventory', 'timestamp': '6/14/2023'}
# Sent inventory message: {'order_id': '38875', 'product_id': '8877', 'quantity': 24, 'type': 'inventory', 'timestamp': '5/2/2023'}
# Sent inventory order: {'order_id': '38875', 'product_id': '8877', 'quantity': 24, 'type': 'inventory', 'timestamp': '5/2/2023'}
# Sent delivery message: {'order_id': '46', 'product_id': '27', 'quantity': 70, 'type': 'delivery', 'timestamp': '2/1/2024'}
# Sent delivery order: {'order_id': '46', 'product_id': '27', 'quantity': 70, 'type': 'delivery', 'timestamp': '2/1/2024'}
# Sent delivery message: {'order_id': '10150', 'product_id': '97', 'quantity': 71, 'type': 'delivery', 'timestamp': '2/28/2024'}
# Sent delivery order: {'order_id': '10150', 'product_id': '97', 'quantity': 71, 'type': 'delivery', 'timestamp': '2/28/2024'}
# Sent delivery message: {'order_id': '372', 'product_id': '70500', 'quantity': 76, 'type': 'delivery', 'timestamp': '4/19/2024'}
# Sent delivery order: {'order_id': '372', 'product_id': '70500', 'quantity': 76, 'type': 'delivery', 'timestamp': '4/19/2024'}
# Sent inventory message: {'order_id': '591', 'product_id': '38393', 'quantity': 69, 'type': 'inventory', 'timestamp': '10/8/2023'}
# Sent inventory order: {'order_id': '591', 'product_id': '38393', 'quantity': 69, 'type': 'inventory', 'timestamp': '10/8/2023'}
# Sent delivery message: {'order_id': '04604', 'product_id': '5153', 'quantity': 71, 'type': 'delivery', 'timestamp': '8/15/2023'}
# Sent delivery order: {'order_id': '04604', 'product_id': '5153', 'quantity': 71, 'type': 'delivery', 'timestamp': '8/15/2023'}
# Sent inventory message: {'order_id': '07', 'product_id': '2', 'quantity': 19, 'type': 'inventory', 'timestamp': '6/16/2023'}
# Sent inventory order: {'order_id': '07', 'product_id': '2', 'quantity': 19, 'type': 'inventory', 'timestamp': '6/16/2023'}
# Sent inventory message: {'order_id': '48050', 'product_id': '463', 'quantity': 69, 'type': 'inventory', 'timestamp': '9/12/2023'}
# Sent inventory order: {'order_id': '48050', 'product_id': '463', 'quantity': 69, 'type': 'inventory', 'timestamp': '9/12/2023'}
# Sent inventory message: {'order_id': '14963', 'product_id': '526', 'quantity': 27, 'type': 'inventory', 'timestamp': '8/20/2023'}
# Sent inventory order: {'order_id': '14963', 'product_id': '526', 'quantity': 27, 'type': 'inventory', 'timestamp': '8/20/2023'}
# Sent inventory message: {'order_id': '9046', 'product_id': '4', 'quantity': 46, 'type': 'inventory', 'timestamp': '2/23/2024'}
# Sent inventory order: {'order_id': '9046', 'product_id': '4', 'quantity': 46, 'type': 'inventory', 'timestamp': '2/23/2024'}
# Sent inventory message: {'order_id': '3265', 'product_id': '4977', 'quantity': 23, 'type': 'inventory', 'timestamp': '4/19/2024'}
# Sent inventory order: {'order_id': '3265', 'product_id': '4977', 'quantity': 23, 'type': 'inventory', 'timestamp': '4/19/2024'}
# Sent delivery message: {'order_id': '6', 'product_id': '886', 'quantity': 56, 'type': 'delivery', 'timestamp': '12/30/2023'}
# Sent delivery order: {'order_id': '6', 'product_id': '886', 'quantity': 56, 'type': 'delivery', 'timestamp': '12/30/2023'}
# Sent inventory message: {'order_id': '590', 'product_id': '389', 'quantity': 72, 'type': 'inventory', 'timestamp': '2/17/2024'}
# Sent inventory order: {'order_id': '590', 'product_id': '389', 'quantity': 72, 'type': 'inventory', 'timestamp': '2/17/2024'}
# Sent inventory message: {'order_id': '2', 'product_id': '33766', 'quantity': 98, 'type': 'inventory', 'timestamp': '4/8/2024'}
# Sent inventory order: {'order_id': '2', 'product_id': '33766', 'quantity': 98, 'type': 'inventory', 'timestamp': '4/8/2024'}
# Sent delivery message: {'order_id': '2484', 'product_id': '41', 'quantity': 89, 'type': 'delivery', 'timestamp': '12/15/2023'}
# Sent delivery order: {'order_id': '2484', 'product_id': '41', 'quantity': 89, 'type': 'delivery', 'timestamp': '12/15/2023'}
# Sent inventory message: {'order_id': '20', 'product_id': '60', 'quantity': 5, 'type': 'inventory', 'timestamp': '2/1/2024'}
# Sent inventory order: {'order_id': '20', 'product_id': '60', 'quantity': 5, 'type': 'inventory', 'timestamp': '2/1/2024'}
# Sent inventory message: {'order_id': '650', 'product_id': '3646', 'quantity': 9, 'type': 'inventory', 'timestamp': '6/26/2023'}
# Sent inventory order: {'order_id': '650', 'product_id': '3646', 'quantity': 9, 'type': 'inventory', 'timestamp': '6/26/2023'}
# Sent delivery message: {'order_id': '17', 'product_id': '8', 'quantity': 10, 'type': 'delivery', 'timestamp': '11/23/2023'}
# Sent delivery order: {'order_id': '17', 'product_id': '8', 'quantity': 10, 'type': 'delivery', 'timestamp': '11/23/2023'}
# Sent inventory message: {'order_id': '2', 'product_id': '4556', 'quantity': 92, 'type': 'inventory', 'timestamp': '7/16/2023'}
# Sent inventory order: {'order_id': '2', 'product_id': '4556', 'quantity': 92, 'type': 'inventory', 'timestamp': '7/16/2023'}
# Sent delivery message: {'order_id': '4', 'product_id': '86143', 'quantity': 59, 'type': 'delivery', 'timestamp': '7/16/2023'}
# Sent delivery order: {'order_id': '4', 'product_id': '86143', 'quantity': 59, 'type': 'delivery', 'timestamp': '7/16/2023'}
# Sent delivery message: {'order_id': '18522', 'product_id': '910', 'quantity': 36, 'type': 'delivery', 'timestamp': '2/27/2024'}
# Sent delivery order: {'order_id': '18522', 'product_id': '910', 'quantity': 36, 'type': 'delivery', 'timestamp': '2/27/2024'}
# Sent delivery message: {'order_id': '096', 'product_id': '6401', 'quantity': 21, 'type': 'delivery', 'timestamp': '9/11/2023'}
# Sent delivery order: {'order_id': '096', 'product_id': '6401', 'quantity': 21, 'type': 'delivery', 'timestamp': '9/11/2023'}
# Sent delivery message: {'order_id': '53481', 'product_id': '6', 'quantity': 26, 'type': 'delivery', 'timestamp': '12/2/2023'}
# Sent delivery order: {'order_id': '53481', 'product_id': '6', 'quantity': 26, 'type': 'delivery', 'timestamp': '12/2/2023'}
# Sent delivery message: {'order_id': '1', 'product_id': '0567', 'quantity': 16, 'type': 'delivery', 'timestamp': '2/17/2024'}
# Sent delivery order: {'order_id': '1', 'product_id': '0567', 'quantity': 16, 'type': 'delivery', 'timestamp': '2/17/2024'}
# Sent inventory message: {'order_id': '1877', 'product_id': '73637', 'quantity': 94, 'type': 'inventory', 'timestamp': '3/18/2024'}
# Sent inventory order: {'order_id': '1877', 'product_id': '73637', 'quantity': 94, 'type': 'inventory', 'timestamp': '3/18/2024'}
# Sent delivery message: {'order_id': '002', 'product_id': '997', 'quantity': 25, 'type': 'delivery', 'timestamp': '3/17/2024'}
# Sent delivery order: {'order_id': '002', 'product_id': '997', 'quantity': 25, 'type': 'delivery', 'timestamp': '3/17/2024'}
# Sent inventory message: {'order_id': '2705', 'product_id': '647', 'quantity': 33, 'type': 'inventory', 'timestamp': '3/25/2024'}
# Sent inventory order: {'order_id': '2705', 'product_id': '647', 'quantity': 33, 'type': 'inventory', 'timestamp': '3/25/2024'}
# Sent delivery message: {'order_id': '18', 'product_id': '81293', 'quantity': 100, 'type': 'delivery', 'timestamp': '10/1/2023'}
# Sent delivery order: {'order_id': '18', 'product_id': '81293', 'quantity': 100, 'type': 'delivery', 'timestamp': '10/1/2023'}
# Sent delivery message: {'order_id': '1867', 'product_id': '1276', 'quantity': 55, 'type': 'delivery', 'timestamp': '10/4/2023'}
# Sent delivery order: {'order_id': '1867', 'product_id': '1276', 'quantity': 55, 'type': 'delivery', 'timestamp': '10/4/2023'}
# Sent inventory message: {'order_id': '411', 'product_id': '8', 'quantity': 32, 'type': 'inventory', 'timestamp': '5/28/2023'}
# Sent inventory order: {'order_id': '411', 'product_id': '8', 'quantity': 32, 'type': 'inventory', 'timestamp': '5/28/2023'}
# Sent delivery message: {'order_id': '871', 'product_id': '181', 'quantity': 18, 'type': 'delivery', 'timestamp': '7/15/2023'}
# Sent delivery order: {'order_id': '871', 'product_id': '181', 'quantity': 18, 'type': 'delivery', 'timestamp': '7/15/2023'}
# Sent delivery message: {'order_id': '2', 'product_id': '9', 'quantity': 21, 'type': 'delivery', 'timestamp': '2/17/2024'}
# Sent delivery order: {'order_id': '2', 'product_id': '9', 'quantity': 21, 'type': 'delivery', 'timestamp': '2/17/2024'}
# Sent delivery message: {'order_id': '461', 'product_id': '12549', 'quantity': 83, 'type': 'delivery', 'timestamp': '4/11/2024'}
# Sent delivery order: {'order_id': '461', 'product_id': '12549', 'quantity': 83, 'type': 'delivery', 'timestamp': '4/11/2024'}
# Sent delivery message: {'order_id': '96687', 'product_id': '6', 'quantity': 98, 'type': 'delivery', 'timestamp': '11/9/2023'}
# Sent delivery order: {'order_id': '96687', 'product_id': '6', 'quantity': 98, 'type': 'delivery', 'timestamp': '11/9/2023'}
# Sent delivery message: {'order_id': '02068', 'product_id': '740', 'quantity': 25, 'type': 'delivery', 'timestamp': '1/13/2024'}
# Sent delivery order: {'order_id': '02068', 'product_id': '740', 'quantity': 25, 'type': 'delivery', 'timestamp': '1/13/2024'}
# Sent inventory message: {'order_id': '74', 'product_id': '15', 'quantity': 32, 'type': 'inventory', 'timestamp': '10/25/2023'}
# Sent inventory order: {'order_id': '74', 'product_id': '15', 'quantity': 32, 'type': 'inventory', 'timestamp': '10/25/2023'}
# Sent delivery message: {'order_id': '44', 'product_id': '979', 'quantity': 86, 'type': 'delivery', 'timestamp': '11/21/2023'}
# Sent delivery order: {'order_id': '44', 'product_id': '979', 'quantity': 86, 'type': 'delivery', 'timestamp': '11/21/2023'}
# Sent delivery message: {'order_id': '499', 'product_id': '78', 'quantity': 70, 'type': 'delivery', 'timestamp': '8/29/2023'}
# ...
# Sent inventory message: {'order_id': '8168', 'product_id': '173', 'quantity': 84, 'type': 'inventory', 'timestamp': '1/25/2024'}
# Sent inventory order: {'order_id': '8168', 'product_id': '173', 'quantity': 84, 'type': 'inventory', 'timestamp': '1/25/2024'}
# Sent inventory message: {'order_id': '06', 'product_id': '2', 'quantity': 6, 'type': 'inventory', 'timestamp': '3/3/2024'}
# Sent inventory order: {'order_id': '06', 'product_id': '2', 'quantity': 6, 'type': 'inventory', 'timestamp': '3/3/2024'}
# Sent delivery message: {'order_id': '437', 'product_id': '31363', 'quantity': 17, 'type': 'delivery', 'timestamp': '8/16/2023'}
# Sent delivery order: {'order_id': '437', 'product_id': '31363', 'quantity': 17, 'type': 'delivery', 'timestamp': '8/16/2023'}
# Sent delivery message: {'order_id': '838', 'product_id': '5', 'quantity': 41, 'type': 'delivery', 'timestamp': '11/12/2023'}
# Sent delivery order: {'order_id': '838', 'product_id': '5', 'quantity': 41, 'type': 'delivery', 'timestamp': '11/12/2023'}
# Sent delivery message: {'order_id': '40', 'product_id': '571', 'quantity': 62, 'type': 'delivery', 'timestamp': '10/12/2023'}
# Sent delivery order: {'order_id': '40', 'product_id': '571', 'quantity': 62, 'type': 'delivery', 'timestamp': '10/12/2023'}
# Sent delivery message: {'order_id': '13977', 'product_id': '8', 'quantity': 13, 'type': 'delivery', 'timestamp': '12/9/2023'}
# Sent delivery order: {'order_id': '13977', 'product_id': '8', 'quantity': 13, 'type': 'delivery', 'timestamp': '12/9/2023'}
# Sent delivery message: {'order_id': '28818', 'product_id': '1970', 'quantity': 9, 'type': 'delivery', 'timestamp': '11/15/2023'}
# Sent delivery order: {'order_id': '28818', 'product_id': '1970', 'quantity': 9, 'type': 'delivery', 'timestamp': '11/15/2023'}
# Sent delivery message: {'order_id': '92', 'product_id': '88688', 'quantity': 90, 'type': 'delivery', 'timestamp': '5/27/2023'}
# Sent delivery order: {'order_id': '92', 'product_id': '88688', 'quantity': 90, 'type': 'delivery', 'timestamp': '5/27/2023'}
# Sent delivery message: {'order_id': '36541', 'product_id': '8447', 'quantity': 48, 'type': 'delivery', 'timestamp': '12/31/2023'}
# Sent delivery order: {'order_id': '36541', 'product_id': '8447', 'quantity': 48, 'type': 'delivery', 'timestamp': '12/31/2023'}
# Sent delivery message: {'order_id': '34784', 'product_id': '0859', 'quantity': 32, 'type': 'delivery', 'timestamp': '6/27/2023'}
# Sent delivery order: {'order_id': '34784', 'product_id': '0859', 'quantity': 32, 'type': 'delivery', 'timestamp': '6/27/2023'}
# Sent delivery message: {'order_id': '7405', 'product_id': '823', 'quantity': 88, 'type': 'delivery', 'timestamp': '11/22/2023'}
# Sent delivery order: {'order_id': '7405', 'product_id': '823', 'quantity': 88, 'type': 'delivery', 'timestamp': '11/22/2023'}
# Sent delivery message: {'order_id': '43', 'product_id': '500', 'quantity': 24, 'type': 'delivery', 'timestamp': '11/24/2023'}
# Sent delivery order: {'order_id': '43', 'product_id': '500', 'quantity': 24, 'type': 'delivery', 'timestamp': '11/24/2023'}
# Sent inventory message: {'order_id': '12451', 'product_id': '1', 'quantity': 78, 'type': 'inventory', 'timestamp': '4/13/2024'}
# Sent inventory order: {'order_id': '12451', 'product_id': '1', 'quantity': 78, 'type': 'inventory', 'timestamp': '4/13/2024'}
# Sent inventory message: {'order_id': '4856', 'product_id': '9', 'quantity': 60, 'type': 'inventory', 'timestamp': '7/14/2023'}
# Sent inventory order: {'order_id': '4856', 'product_id': '9', 'quantity': 60, 'type': 'inventory', 'timestamp': '7/14/2023'}
# Sent delivery message: {'order_id': '6817', 'product_id': '2522', 'quantity': 96, 'type': 'delivery', 'timestamp': '12/3/2023'}
# Sent delivery order: {'order_id': '6817', 'product_id': '2522', 'quantity': 96, 'type': 'delivery', 'timestamp': '12/3/2023'}
# Sent delivery message: {'order_id': '925', 'product_id': '21', 'quantity': 15, 'type': 'delivery', 'timestamp': '8/29/2023'}
# Sent delivery order: {'order_id': '925', 'product_id': '21', 'quantity': 15, 'type': 'delivery', 'timestamp': '8/29/2023'}
# Sent inventory message: {'order_id': '90', 'product_id': '3511', 'quantity': 88, 'type': 'inventory', 'timestamp': '2/21/2024'}
# Sent inventory order: {'order_id': '90', 'product_id': '3511', 'quantity': 88, 'type': 'inventory', 'timestamp': '2/21/2024'}
# Sent delivery message: {'order_id': '9003', 'product_id': '1', 'quantity': 73, 'type': 'delivery', 'timestamp': '2/3/2024'}
# Sent delivery order: {'order_id': '9003', 'product_id': '1', 'quantity': 73, 'type': 'delivery', 'timestamp': '2/3/2024'}
# Sent inventory message: {'order_id': '49078', 'product_id': '2363', 'quantity': 83, 'type': 'inventory', 'timestamp': '1/13/2024'}
# Sent inventory order: {'order_id': '49078', 'product_id': '2363', 'quantity': 83, 'type': 'inventory', 'timestamp': '1/13/2024'}
# Sent inventory message: {'order_id': '1', 'product_id': '34', 'quantity': 35, 'type': 'inventory', 'timestamp': '7/27/2023'}
# Sent inventory order: {'order_id': '1', 'product_id': '34', 'quantity': 35, 'type': 'inventory', 'timestamp': '7/27/2023'}
# Sent inventory message: {'order_id': '86558', 'product_id': '56093', 'quantity': 68, 'type': 'inventory', 'timestamp': '1/24/2024'}
# Sent inventory order: {'order_id': '86558', 'product_id': '56093', 'quantity': 68, 'type': 'inventory', 'timestamp': '1/24/2024'}
# Sent delivery message: {'order_id': '49', 'product_id': '3697', 'quantity': 55, 'type': 'delivery', 'timestamp': '9/15/2023'}
# Sent delivery order: {'order_id': '49', 'product_id': '3697', 'quantity': 55, 'type': 'delivery', 'timestamp': '9/15/2023'}
# Sent delivery message: {'order_id': '76370', 'product_id': '17', 'quantity': 41, 'type': 'delivery', 'timestamp': '11/25/2023'}
# Sent delivery order: {'order_id': '76370', 'product_id': '17', 'quantity': 41, 'type': 'delivery', 'timestamp': '11/25/2023'}
# Sent delivery message: {'order_id': '8', 'product_id': '5510', 'quantity': 60, 'type': 'delivery', 'timestamp': '12/28/2023'}
# Sent delivery order: {'order_id': '8', 'product_id': '5510', 'quantity': 60, 'type': 'delivery', 'timestamp': '12/28/2023'}
# Sent inventory message: {'order_id': '5703', 'product_id': '53941', 'quantity': 20, 'type': 'inventory', 'timestamp': '4/1/2024'}
# Sent inventory order: {'order_id': '5703', 'product_id': '53941', 'quantity': 20, 'type': 'inventory', 'timestamp': '4/1/2024'}
# Sent inventory message: {'order_id': '256', 'product_id': '323', 'quantity': 34, 'type': 'inventory', 'timestamp': '8/4/2023'}
# Sent inventory order: {'order_id': '256', 'product_id': '323', 'quantity': 34, 'type': 'inventory', 'timestamp': '8/4/2023'}
# Sent inventory message: {'order_id': '59955', 'product_id': '40', 'quantity': 3, 'type': 'inventory', 'timestamp': '6/14/2023'}
# Sent inventory order: {'order_id': '59955', 'product_id': '40', 'quantity': 3, 'type': 'inventory', 'timestamp': '6/14/2023'}
# Sent inventory message: {'order_id': '7', 'product_id': '7855', 'quantity': 21, 'type': 'inventory', 'timestamp': '1/27/2024'}
# Sent inventory order: {'order_id': '7', 'product_id': '7855', 'quantity': 21, 'type': 'inventory', 'timestamp': '1/27/2024'}
# Sent inventory message: {'order_id': '1789', 'product_id': '85', 'quantity': 84, 'type': 'inventory', 'timestamp': '12/26/2023'}
# Sent inventory order: {'order_id': '1789', 'product_id': '85', 'quantity': 84, 'type': 'inventory', 'timestamp': '12/26/2023'}
# Sent delivery message: {'order_id': '1', 'product_id': '99561', 'quantity': 18, 'type': 'delivery', 'timestamp': '1/1/2024'}
# Sent delivery order: {'order_id': '1', 'product_id': '99561', 'quantity': 18, 'type': 'delivery', 'timestamp': '1/1/2024'}
# Sent inventory message: {'order_id': '5', 'product_id': '9', 'quantity': 74, 'type': 'inventory', 'timestamp': '6/14/2023'}
# Sent inventory order: {'order_id': '5', 'product_id': '9', 'quantity': 74, 'type': 'inventory', 'timestamp': '6/14/2023'}
# Sent inventory message: {'order_id': '858', 'product_id': '336', 'quantity': 76, 'type': 'inventory', 'timestamp': '4/11/2024'}
# Sent inventory order: {'order_id': '858', 'product_id': '336', 'quantity': 76, 'type': 'inventory', 'timestamp': '4/11/2024'}
# Sent delivery message: {'order_id': '79', 'product_id': '90', 'quantity': 52, 'type': 'delivery', 'timestamp': '10/4/2023'}
# Sent delivery order: {'order_id': '79', 'product_id': '90', 'quantity': 52, 'type': 'delivery', 'timestamp': '10/4/2023'}
# Sent inventory message: {'order_id': '656', 'product_id': '277', 'quantity': 21, 'type': 'inventory', 'timestamp': '1/7/2024'}
# Sent inventory order: {'order_id': '656', 'product_id': '277', 'quantity': 21, 'type': 'inventory', 'timestamp': '1/7/2024'}
# Sent delivery message: {'order_id': '9', 'product_id': '4998', 'quantity': 26, 'type': 'delivery', 'timestamp': '12/29/2023'}
# Sent delivery order: {'order_id': '9', 'product_id': '4998', 'quantity': 26, 'type': 'delivery', 'timestamp': '12/29/2023'}
# Sent inventory message: {'order_id': '748', 'product_id': '3271', 'quantity': 82, 'type': 'inventory', 'timestamp': '10/27/2023'}
# Sent inventory order: {'order_id': '748', 'product_id': '3271', 'quantity': 82, 'type': 'inventory', 'timestamp': '10/27/2023'}
# Sent inventory message: {'order_id': '96884', 'product_id': '1', 'quantity': 87, 'type': 'inventory', 'timestamp': '1/15/2024'}
# Sent inventory order: {'order_id': '96884', 'product_id': '1', 'quantity': 87, 'type': 'inventory', 'timestamp': '1/15/2024'}
# Sent delivery message: {'order_id': '9860', 'product_id': '4', 'quantity': 40, 'type': 'delivery', 'timestamp': '6/28/2023'}
# Sent delivery order: {'order_id': '9860', 'product_id': '4', 'quantity': 40, 'type': 'delivery', 'timestamp': '6/28/2023'}
# Sent delivery message: {'order_id': '8692', 'product_id': '3138', 'quantity': 5, 'type': 'delivery', 'timestamp': '2/2/2024'}
# Sent delivery order: {'order_id': '8692', 'product_id': '3138', 'quantity': 5, 'type': 'delivery', 'timestamp': '2/2/2024'}
# Sent inventory message: {'order_id': '74854', 'product_id': '73', 'quantity': 68, 'type': 'inventory', 'timestamp': '2/4/2024'}
# Sent inventory order: {'order_id': '74854', 'product_id': '73', 'quantity': 68, 'type': 'inventory', 'timestamp': '2/4/2024'}
# Sent delivery message: {'order_id': '4373', 'product_id': '482', 'quantity': 28, 'type': 'delivery', 'timestamp': '11/23/2023'}
# Sent delivery order: {'order_id': '4373', 'product_id': '482', 'quantity': 28, 'type': 'delivery', 'timestamp': '11/23/2023'}
# Sent delivery message: {'order_id': '32', 'product_id': '9', 'quantity': 19, 'type': 'delivery', 'timestamp': '12/5/2023'}
# Sent delivery order: {'order_id': '32', 'product_id': '9', 'quantity': 19, 'type': 'delivery', 'timestamp': '12/5/2023'}
# Sent delivery message: {'order_id': '09614', 'product_id': '72424', 'quantity': 55, 'type': 'delivery', 'timestamp': '9/15/2023'}
# Sent delivery order: {'order_id': '09614', 'product_id': '72424', 'quantity': 55, 'type': 'delivery', 'timestamp': '9/15/2023'}
# Sent delivery message: {'order_id': '672', 'product_id': '4', 'quantity': 12, 'type': 'delivery', 'timestamp': '8/9/2023'}
# Sent delivery order: {'order_id': '672', 'product_id': '4', 'quantity': 12, 'type': 'delivery', 'timestamp': '8/9/2023'}
# Sent inventory message: {'order_id': '68102', 'product_id': '2222', 'quantity': 35, 'type': 'inventory', 'timestamp': '3/7/2024'}
# Sent inventory order: {'order_id': '68102', 'product_id': '2222', 'quantity': 35, 'type': 'inventory', 'timestamp': '3/7/2024'}
# Sent inventory message: {'order_id': '45190', 'product_id': '4693', 'quantity': 52, 'type': 'inventory', 'timestamp': '12/12/2023'}
# Sent inventory order: {'order_id': '45190', 'product_id': '4693', 'quantity': 52, 'type': 'inventory', 'timestamp': '12/12/2023'}
# Sent inventory message: {'order_id': '221', 'product_id': '40769', 'quantity': 42, 'type': 'inventory', 'timestamp': '12/24/2023'}
# Sent inventory order: {'order_id': '221', 'product_id': '40769', 'quantity': 42, 'type': 'inventory', 'timestamp': '12/24/2023'}
# Sent delivery message: {'order_id': '1', 'product_id': '41553', 'quantity': 21, 'type': 'delivery', 'timestamp': '5/31/2023'}
# Sent delivery order: {'order_id': '1', 'product_id': '41553', 'quantity': 21, 'type': 'delivery', 'timestamp': '5/31/2023'}
# Sent delivery message: {'order_id': '3848', 'product_id': '9', 'quantity': 25, 'type': 'delivery', 'timestamp': '10/1/2023'}
# Sent delivery order: {'order_id': '3848', 'product_id': '9', 'quantity': 25, 'type': 'delivery', 'timestamp': '10/1/2023'}
# Sent delivery message: {'order_id': '093', 'product_id': '75', 'quantity': 40, 'type': 'delivery', 'timestamp': '9/18/2023'}
# Sent delivery order: {'order_id': '093', 'product_id': '75', 'quantity': 40, 'type': 'delivery', 'timestamp': '9/18/2023'}
# Sent delivery message: {'order_id': '9', 'product_id': '401', 'quantity': 89, 'type': 'delivery', 'timestamp': '4/25/2024'}
# Sent delivery order: {'order_id': '9', 'product_id': '401', 'quantity': 89, 'type': 'delivery', 'timestamp': '4/25/2024'}
# Sent inventory message: {'order_id': '0', 'product_id': '4153', 'quantity': 59, 'type': 'inventory', 'timestamp': '5/30/2023'}
# Sent inventory order: {'order_id': '0', 'product_id': '4153', 'quantity': 59, 'type': 'inventory', 'timestamp': '5/30/2023'}
# Sent inventory message: {'order_id': '3952', 'product_id': '311', 'quantity': 15, 'type': 'inventory', 'timestamp': '2/22/2024'}
# Sent inventory order: {'order_id': '3952', 'product_id': '311', 'quantity': 15, 'type': 'inventory', 'timestamp': '2/22/2024'}
# Sent inventory message: {'order_id': '703', 'product_id': '39', 'quantity': 96, 'type': 'inventory', 'timestamp': '8/24/2023'}
# Sent inventory order: {'order_id': '703', 'product_id': '39', 'quantity': 96, 'type': 'inventory', 'timestamp': '8/24/2023'}
# Sent inventory message: {'order_id': '9049', 'product_id': '1', 'quantity': 28, 'type': 'inventory', 'timestamp': '5/10/2023'}
# Sent inventory order: {'order_id': '9049', 'product_id': '1', 'quantity': 28, 'type': 'inventory', 'timestamp': '5/10/2023'}
# Sent inventory message: {'order_id': '2351', 'product_id': '951', 'quantity': 20, 'type': 'inventory', 'timestamp': '10/31/2023'}
# Sent inventory order: {'order_id': '2351', 'product_id': '951', 'quantity': 20, 'type': 'inventory', 'timestamp': '10/31/2023'}
# Sent delivery message: {'order_id': '9201', 'product_id': '96611', 'quantity': 1, 'type': 'delivery', 'timestamp': '8/31/2023'}
# Sent delivery order: {'order_id': '9201', 'product_id': '96611', 'quantity': 1, 'type': 'delivery', 'timestamp': '8/31/2023'}
# Sent delivery message: {'order_id': '06', 'product_id': '89462', 'quantity': 66, 'type': 'delivery', 'timestamp': '1/17/2024'}
# Sent delivery order: {'order_id': '06', 'product_id': '89462', 'quantity': 66, 'type': 'delivery', 'timestamp': '1/17/2024'}
# Sent inventory message: {'order_id': '2157', 'product_id': '83', 'quantity': 57, 'type': 'inventory', 'timestamp': '9/3/2023'}
# Sent inventory order: {'order_id': '2157', 'product_id': '83', 'quantity': 57, 'type': 'inventory', 'timestamp': '9/3/2023'}
# Sent delivery message: {'order_id': '86604', 'product_id': '65', 'quantity': 54, 'type': 'delivery', 'timestamp': '10/4/2023'}
# Sent delivery order: {'order_id': '86604', 'product_id': '65', 'quantity': 54, 'type': 'delivery', 'timestamp': '10/4/2023'}
# Sent delivery message: {'order_id': '7509', 'product_id': '7253', 'quantity': 3, 'type': 'delivery', 'timestamp': '12/2/2023'}
# Sent delivery order: {'order_id': '7509', 'product_id': '7253', 'quantity': 3, 'type': 'delivery', 'timestamp': '12/2/2023'}
# Sent inventory message: {'order_id': '797', 'product_id': '02461', 'quantity': 97, 'type': 'inventory', 'timestamp': '8/18/2023'}
# Sent inventory order: {'order_id': '797', 'product_id': '02461', 'quantity': 97, 'type': 'inventory', 'timestamp': '8/18/2023'}
# Sent delivery message: {'order_id': '87', 'product_id': '05', 'quantity': 85, 'type': 'delivery', 'timestamp': '11/2/2023'}
# Sent delivery order: {'order_id': '87', 'product_id': '05', 'quantity': 85, 'type': 'delivery', 'timestamp': '11/2/2023'}
